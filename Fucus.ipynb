# %% [markdown]
# <a href="https://colab.research.google.com/github/SamManikshaw/Video-Encoder-Bot/blob/main/Fucus.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pygit2==1.12.2
# %cd /content
# !git clone https://github.com/lllyasviel/Fooocus.git
# %cd /content/Fooocus
# !python entry_with_update.py --share --always-high-vram
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 15.5 MB/s eta 0:00:00
# ...
# /content
# Cloning into 'Fooocus'...
# remote: Enumerating objects: 6177, done.
# remote: Counting objects: 100% (226/226), done.
# remote: Compressing objects: 100% (153/153), done.
# remote: Total 6177 (delta 111), reused 144 (delta 61), pack-reused 5951
# Receiving objects: 100% (6177/6177), 33.01 MiB | 25.59 MiB/s, done.
# Resolving deltas: 100% (3480/3480), done.
# /content/Fooocus
# Already up-to-date
# Update succeeded.
# [System ARGV] ['entry_with_update.py', '--share', '--always-high-vram']
# Python 3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0]
# Fooocus version: 2.4.1
# Error checking version for torchsde: No package metadata was found for torchsde
# Installing requirements
# [Cleanup] Attempting to delete content of temp dir /tmp/fooocus
# [Cleanup] Cleanup successful
# ...
